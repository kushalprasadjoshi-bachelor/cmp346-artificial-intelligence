# %% [markdown]
# # Python Basics

# %%
a = 10
b = 11.5
c = 'Hello World'
d = True

# %%
print(a)
print(b)
print(c)
print(d)

print(a,b,c,d)
# Out:
# 10
# 11.5
# Hello World
# True
# 10 11.5 Hello World True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Arithmetic Operators
# ```
#  + - * / % ** //
# ```

# %%
a = 10
b = 3
c = a % b
print(c)
# Out:
# 1

# %%
a = 10
b = 2
c = a ** b  #  b is power of a
print(c)
# Out:
# 25

# %%
a = 11
b = 3
c = a // b  # Floor Division( integer division)
print(c)
# Out:
# 3

# %%
a = '10'
b = '3'
print(a+b)
# Out:
# 103

# %%
a = "Hello"
b = " World"
c = a+b
print(c)
# Out:
# Hello World

# %%
a = "Hello World\n"
print(a*2)  #print a 2 times
# Out:
# Hello World
# Hello World

# %%
a = "Messi "
b = '10'
c = a+b
c
# Out:
# 'Messi 10'

# %%
a = True
b = False
c = a+b
print(c)
# Out:
# 1

# %%
a = True
b = True
c = a+b
print(c)
# Out:
# 2

# %% [markdown]
# ## Complex Numbers

# %%
a = 1+2j
a

# %%
(0+1j)*(0+1j)
# Out:
# (-1+0j)

# %% [markdown]
# ## Type Casting

# %%
# Type casting
# str() int() float()
a = 10
b = str(a)
b
# Out:
# '10'

# %%
a = '20'
int(a)
# Out:
# 20

# %%
a = '20.5'
float(a)
# Out:
# 20.5

# %% [markdown]
# ## Basic I/O

# %%
a = input()
print(a)

# %%
a = input("Enter a = ")
print(a)

# %%
a = input("Enter a = ")  # a is a string
b = input("Enter b = ")  #b is a string
print(a+b)
# Out:
# Enter a = 10
# Enter b = 20
# 1020

# %%
a = int(input("Enter a = "))
b = int(input("Enter b = "))
print(a+b)
# Out:
# Enter a = 10
# Enter b = 20
# 30

# %%
p = int(input("Enter p = "))
t = float(input("Enter t = "))
r = float(input("Enter r = "))
i = p*t*r/100
print("The value of i = ",i)
# Out:
# Enter p = 10000
# Enter t = 3.5
# Enter r = 10.4
# The value of i =  3640.0

# %% [markdown]
# ## Conditions
#
# ```python
# if <condation>:
#     <operations>
# elif <condition>:
#     <operations>
# ...
#
# else:
#     <operation>
# > < >= <= == !=
# ```

# %%
a = 10
print(a<0)
print(a>0)
# Out:
# False
# True

# %%
a = int(input("Enter a = "))
# print(a%2==0)
if a%2==0:
    print(a," is even")
else:
    print(a," is odd")
# Out:
# 12  is even

# %%
physics = int(input("Enter physics marks = "))
chemistry = int(input("Enter chemistry marks = "))
math = int(input("Enter math marks = "))
english = int(input("Enter english marks = "))
nepali = int(input("Enter nepali marks = "))

total = physics+chemistry+math+english+nepali
per = total/5

if per >= 80:
    grade = 'A'
elif per >=60:
    grade = 'B'
elif per >= 45:
    grade = 'C'
else:
    grade = 'F'

print("Total = ",total)
print("Per = ",per)
print("Grade = ",grade)
# Out:
# Total =  335
# Per =  67.0
# Grade =  B

# %%
a = int(input("Enter a = "))
b = int(input("Enter b = "))
o = input("Enter o = ")
if o == '+':
    print(a+b)
elif o == '-':
    print(a-b)
elif o == '*':
    print(a*b)
elif o == '/':
    if b != 0:
        print(a/b)
    else:
        print("The vale of b can not be zero.")
else:
    print("Enter Valid Operator")
# Out:
# 40
